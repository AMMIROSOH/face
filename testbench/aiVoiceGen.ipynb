# %%
from openai import OpenAI
client = OpenAI()

# %%
name = "nova"
with client.audio.speech.with_streaming_response.create(
    model="gpt-4o-mini-tts",
    voice=name,
    input="Welcome to the High-Performance Face Recognition demo. With TensorRT and Python multiprocessing, every subsystem is individually optimized to run smoothly — reaching highest frames per seconds with no drops. Want step-by-step tutorials? Drop a comment below!"
) as response:
    response.stream_to_file(f"{name}.mp3")
